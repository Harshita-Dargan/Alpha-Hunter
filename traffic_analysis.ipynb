# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita-Dargan/Alpha-Hunter/blob/main/traffic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Using a yolo model to analyse traffic
# !mkdir datset
# Install or upgrade the ultralytics package from PyPI
# !pip install -U ultralytics
# Out:
# mkdir: cannot create directory ‘datset’: File exists
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 647.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !ffmpeg -version
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !ffmpeg -i traffic2.mp4 -vf "fps=2" /content/datset/frame_%04d.png
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !zip -r dataset.zip /content/datset
# Out:
#   adding: content/datset/ (stored 0%)
#   adding: content/datset/frame_0021.png (deflated 0%)
#   adding: content/datset/frame_0018.png (deflated 0%)
#   adding: content/datset/frame_0024.png (deflated 0%)
#   adding: content/datset/frame_0009.png (deflated 0%)
#   adding: content/datset/frame_0016.png (deflated 0%)
#   adding: content/datset/frame_0017.png (deflated 0%)
#   adding: content/datset/frame_0013.png (deflated 0%)
#   adding: content/datset/frame_0030.png (deflated 0%)
#   adding: content/datset/frame_0007.png (deflated 0%)
#   adding: content/datset/frame_0005.png (deflated 0%)
#   adding: content/datset/frame_0014.png (deflated 0%)
#   adding: content/datset/frame_0026.png (deflated 0%)
#   adding: content/datset/frame_0003.png (deflated 0%)
#   adding: content/datset/frame_0025.png (deflated 0%)
#   adding: content/datset/frame_0012.png (deflated 0%)
#   adding: content/datset/frame_0029.png (deflated 0%)
#   adding: content/datset/frame_0010.png (deflated 0%)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n-cls.yaml")  # build a new model from YAML
model = YOLO("yolo26n-cls.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo26n-cls.yaml").load("yolo26n-cls.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="mnist160", epochs=100, imgsz=64)
